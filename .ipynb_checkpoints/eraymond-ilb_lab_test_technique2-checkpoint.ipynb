# %% [markdown]
# # [Test Technique 2] - @Elouan RAYMOND

# %% [markdown]
# ## Consignes
#
# L’objectif est de développer **un modèle performant** pour prédire la **variable Output** en fonction des **autres variables pertinentes**. La plupart des variables ont un nom décrivant l’information contenue.
#
#
#
# **Quelques informations :**
#
# * Les variables finissant en _M : variables calculées au mois M
# * Les variables finissant en _MY : variables calculées au mois M-Y
# * Les variables finissant en _XM : variables calculées sur les mois M-X au mois M

# %% [markdown]
# # Sommaire

# %% [markdown]
# > Je vais présenter ici de façon succincte l'organisation que j'ai adopté" pour mon analyse et le cheminement.
#
# **Progression**
#
# [Lecture du fichier](#1.-Lecture-du-fichier-&-Reformatages)
# <br>
#
# * Il faut tout d'abord charger le jeu de données correctement et reformater certaines données donc la lecture aurait pu échouer.
#
# [Première exploration du dataset](#1.2---Répartition-des-données-et-outliers)
# <br>
#
# * Afficher les  variables du dataset, afin de voir si certaines données doivent être filtrées (outliers qui n'auraient pas sens notamment)
#
# [Seconde exploration du dataset](#2.-Analyse-des-données)
#
# * [Donner du sens aux variables, analyser les corrélations](#2.1-Analyse-des-features-&-output)
# * [Analyser l'output et donner des pistes pour le modèle](#Analyse-de-[Output])
# * [Signification d'output](#Signification-d'Output)
#
# [Choix de la modélisation](#3.-Choix-de-la-modélisation)
# * Choix des modèles
# * Choix des métriques
# * Objectifs
#
#
# [Réduction du nombre de variables](#4.-Analyse-en-Composante-Principale)
# * Réduire le nombre de variables afin de mener une analyse plus pertinente
# <br>
#
#
# [$1^{er}$ modèle d'apprentissage supervisé](#5---Classification-avec-un-SVC-:-Support-Vector-Machine-Classifier)
#
# * [Optimisation des hyperparamètres](#5.2.-Optimisation-des-hyperparamètres)
# * [Calcul des métriques](#5.3.-Performance-du-modèle)
#
# [$2^{nd}$ modèle d'apprentissage supervisé](#6.-Classification-avec-un-Random-Forest)
#
# * [Optimisation des hyperparamètres](#6.2.-Optimisation-des-hyperparamètres)
# * [Calcul des métriques](#6.3.-Performance-du-modèle)
#
# [Amélioration des modèles](#7.-Amélioration-des-modèles-avec-certaines-sélections-de-features)
#
# [Conclusion](#Conclusion)
# * [Retour sur l'objectif](#Retour-sur-les-données)
# * [Pistes](#Quelques-pistes)

# %% [markdown]
# ### Librairies pour l'analyse

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %% [markdown]
# # 1. Lecture du fichier & Reformatages
# ## Chargement des données

# %%
df = pd.read_csv('Dataset_test_ILB.csv',encoding="latin1",sep=';',decimal=',')
# Encodage latin1 car le fichier n'est pas encodé en UTF8, selection de "," en séparateur décimal

# %% [markdown]
# ## 1.1  Analyse du format
#
# > L'objectif est de s'assurer ici que la lecture du fichier a été réussie et de reformater si nécessaire certaines données.

# %%
df.head()
# Out:
#      ID  Nombres_adultes  Nombre_personnes_foyer  Age_2eme_personne  \
# 0  2911         2.057430                2.070880          91.042848
# 1  1398         2.060715                2.193722          90.715413
# 2  1793         1.930472                1.946847          90.588554
# 3  1193         1.963631                1.916677          89.300012
# 4  1342         2.009754                2.019892          87.706161
#
#    Note_credit Encours_credit                                     ID_PP  \
# 0     0.177448     4715,49819  732f2de9240c404122f8c97b952c4cb8be8ede7f
# 1    -0.062708    6584,320922  1cc77d640ec2c383bef7099ff331d2ae962fd712
# 2    -0.094438   -7792,256696  34d7809e534d6e7d83e1439cd4032201386fe9dd
# 3    -0.286729    6118,791869  1539c6f04d9403928ef4e5b662490bd4787ad71d
# 4     0.284325   -4266,843489  27524f055875f70d102006ee6dcb360e982c4a69
#
#    Encours_credit_habitat  Montant_flux_crediteur_M1  Montant_obligations  \
# 0             2772.907651                9005.374276          5897.737602
# 1             7094.588072                5047.824214         55655.446030
# 2            -7613.883523                -692.852208          2277.193995
# 3             5874.214001                1408.588664          8280.325647
# 4            -4459.202674                -889.296675         59977.521970
#
#    ...  Nombre_retrait_carte_M1  Nombre_retrait_carte_M1,1  \
# 0  ...                 0.160537                   0.094456
# 1  ...                -0.172851                  -0.170338
# 2  ...                -0.037880                  -0.086625
# 3  ...                 0.994902                   0.001148
# 4  ...                -0.027045                   0.080714
#
#    Quantité_obligations  Nombre_connexion_appli_6M  \
# 0          262736.76140                  46.683372
# 1          157962.64670                   6.806368
# 2          -26034.01144                   3.442761
# 3          336491.25330                  -6.298359
# 4          -10631.26532                   3.056277
#
#    Nombre_de_connexion_appli_semaine_6M  Nombre_connexion_site_6M  \
# 0                             41.184480                 48.057303
# 1                              9.210575                 12.027955
# 2                              4.988904                  7.072354
# 3                             -7.873857                 -9.758806
# 4                              4.414500                  5.862660
#
#   Duree_connexion_moyenne_6M  Montant_flux_crediteur_M  Montant_pret_banque  \
# 0                  28.811906               5757.583993          124370.2918
# 1                  -8.664351               2825.730247          130015.4600
# 2                 -21.135796               1679.601033          130904.7126
# 3                  -6.232009               4059.963478          123729.3778
# 4                 -28.520162               1719.696619          126770.7544
#
#    Output
# 0    FAUX
# 1    FAUX
# 2    FAUX
# 3    FAUX
# 4    FAUX
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (3015, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3015 entries, 0 to 3014
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID                                    3015 non-null   int64
#  1   Nombres_adultes                       3005 non-null   float64
#  2   Nombre_personnes_foyer                3006 non-null   float64
#  3   Age_2eme_personne                     3013 non-null   float64
#  4   Note_credit                           3010 non-null   float64
#  5   Encours_credit                        2993 non-null   object
#  6   ID_PP                                 3008 non-null   object
#  7   Encours_credit_habitat                3011 non-null   float64
#  8   Montant_flux_crediteur_M1             3011 non-null   float64
#  9   Montant_obligations                   3011 non-null   float64
#  10  Montant_operation_crediteur_DAV_M1    3002 non-null   float64
#  11  Montant_operation_crediteur_DAV_M     2994 non-null   float64
#  12  Montant_operation_debiteur_DAV_M1     2979 non-null   float64
#  13  Montant_operation_debiteur_DAV_M      2980 non-null   float64
#  14  Montant_retrait_carte_M               2998 non-null   float64
#  15  Montant_retrait_carte_M1              3008 non-null   float64
#  16  CSP                                   3010 non-null   object
#  17  Nombre_retrait_carte_M1               3011 non-null   float64
#  18  Nombre_retrait_carte_M1,1             3010 non-null   float64
#  19  Quantité_obligations                  3009 non-null   float64
#  20  Nombre_connexion_appli_6M             2994 non-null   float64
#  21  Nombre_de_connexion_appli_semaine_6M  2994 non-null   float64
#  22  Nombre_connexion_site_6M              2996 non-null   float64
#  23  Duree_connexion_moyenne_6M            3006 non-null   float64
#  24  Montant_flux_crediteur_M              3009 non-null   float64
#  25  Montant_pret_banque                   3008 non-null   float64
#  26  Output                                3007 non-null   object
# dtypes: float64(22), int64(1), object(4)
# memory usage: 636.1+ KB

# %% [markdown]
# ### Problème de conversion sur Encours_credit
# La majorité des colonnes qui contiennent des float ont bien été converties, sauf **Encours_credit**
# > **Encours_credit**: Argent qui a été prêté mais qui n'a pas encore été remboursé.

# %% [markdown]
# ### [Encours_credit]  - Reformatage
#
# Nous allons donc reformater cette colonne de valeur afin de pouvoir mener des analyses

# %%
df.Encours_credit[14:34]
# Out:
# 14    PAS DENCOURS
# 15    -4648,965858
# 16     9654,794858
# 17    -14351,44645
# 18    -1636,208879
# 19    -9442,465683
# 20    -8047,237148
# 21    -2059,018592
# 22     3981,916098
# 23     -2517,34467
# 24    -6878,210721
# 25     182,6623636
# 26    -5287,245058
# 27    -10360,55858
# 28      11300,4433
# 29    -3482,976268
# 30     10768,15036
# 31    -18316,31167
# 32     2641,386869
# 33             NaN
# Name: Encours_credit, dtype: object

# %% [markdown]
# <br>
# On comprend mieux pourquoi la conversion n'a pas pu se faire: il faut prendre en compte les personnes qui n'ont pas d'encours crédit (PAS DENCOURS), ou pour lesquelles on ne connaît pas l'information (NaN)

# %% [markdown]
# #### Formatage d'encours_credit
#
# Pour que l'encours crédit garde son sens, je propose de séparer cette colonne en deux colonnes :
#
# | Encours_credit_bool             | Encours_credit_value |
# | ------------------------------- | -------------------- |
# | 1 (True)                            | -1151                |
# | 0 (False (Remplace 'PAS DENCOURS')) | NaN                  |

# %%
"""Création de deux array encours_credit_bool & encours_credit_value """
def create_encours_credit_bool_and_value(df):
    encours_credit = df['Encours_credit'].tolist()
    """Fonction qui construit les deux array évoqués ci-dessus"""
    encours_credit_bool = [1]*len(encours_credit)
    encours_credit_value =[np.nan]*len(encours_credit)
    for (i,encours) in enumerate(encours_credit): 
        """Parcourt la liste encours_credit : encours est un str pour le moment"""
        if encours =="PAS DENCOURS":
            encours_credit_bool[i] = 0
        else : 
            """Il y a bien un encours, il va falloir convertir le str en float : attention sep ',' """
            try :
                """Il se peut que encours soit un NaN c'est pourquoi on utilise try & except"""
                encours_float = '.'.join(encours.split(',')) # Utilisation de split pour la conversion
                encours_float = float(encours_float)
                encours_credit_value[i] = encours_float
            except : 
                encours_credit_bool[i] = np.nan
                
    """On peut renvoyer les array"""
    return(encours_credit_bool,encours_credit_value)

# %%
encours_credit_bool,encours_credit_values = create_encours_credit_bool_and_value(df)

# %% [markdown]
# **On vérifie si la structure est conforme à ce que nous avions envisagé**

# %%
encours = pd.DataFrame(zip(encours_credit_bool,encours_credit_values),columns=['Encours_credit_bool','Encours_credit_value'])

# %%
encours.iloc[13:34,:]
## Le reformatage a bien fonctionné
# Out:
#     Encours_credit_bool  Encours_credit_value
# 13                  1.0           5286.493638
# 14                  0.0                   NaN
# 15                  1.0          -4648.965858
# 16                  1.0           9654.794858
# 17                  1.0         -14351.446450
# 18                  1.0          -1636.208879
# 19                  1.0          -9442.465683
# 20                  1.0          -8047.237148
# 21                  1.0          -2059.018592
# 22                  1.0           3981.916098
# 23                  1.0          -2517.344670
# 24                  1.0          -6878.210721
# 25                  1.0            182.662364
# 26                  1.0          -5287.245058
# 27                  1.0         -10360.558580
# 28                  1.0          11300.443300
# 29                  1.0          -3482.976268
# 30                  1.0          10768.150360
# 31                  1.0         -18316.311670
# 32                  1.0           2641.386869
# 33                  NaN                   NaN

# %% [markdown]
# ### Modification d'encours cr"dit dans le dataframe

# %%
df1 = df.copy()

# %% [markdown]
# On va insérer notre notre dataframe encours à la place de 'Encours_credit'

# %%
df1.iloc[:2,:5]
# Out:
#      ID  Nombres_adultes  Nombre_personnes_foyer  Age_2eme_personne  \
# 0  2911         2.057430                2.070880          91.042848
# 1  1398         2.060715                2.193722          90.715413
#
#    Note_credit
# 0     0.177448
# 1    -0.062708

# %%
encours.head(2)
# Out:
#    Encours_credit_bool  Encours_credit_value
# 0                  1.0           4715.498190
# 1                  1.0           6584.320922

# %%
df1.iloc[:2,6:]
# Out:
#                                       ID_PP  Encours_credit_habitat  \
# 0  732f2de9240c404122f8c97b952c4cb8be8ede7f             2772.907651
# 1  1cc77d640ec2c383bef7099ff331d2ae962fd712             7094.588072
#
#    Montant_flux_crediteur_M1  Montant_obligations  \
# 0                9005.374276          5897.737602
# 1                5047.824214         55655.446030
#
#    Montant_operation_crediteur_DAV_M1  Montant_operation_crediteur_DAV_M  \
# 0                         4498.397638                        7930.203493
# 1                         1890.630239                       -1655.250533
#
#    Montant_operation_debiteur_DAV_M1  Montant_operation_debiteur_DAV_M  \
# 0                        4997.109487                       9488.923224
# 1                        1669.661800                       1494.971252
#
#    Montant_retrait_carte_M  Montant_retrait_carte_M1  ...  \
# 0                31.338746                 25.008051  ...
# 1                -0.191790                 -3.399387  ...
#
#   Nombre_retrait_carte_M1  Nombre_retrait_carte_M1,1  Quantité_obligations  \
# 0                0.160537                   0.094456           262736.7614
# 1               -0.172851                  -0.170338           157962.6467
#
#    Nombre_connexion_appli_6M  Nombre_de_connexion_appli_semaine_6M  \
# 0                  46.683372                             41.184480
# 1                   6.806368                              9.210575
#
#    Nombre_connexion_site_6M  Duree_connexion_moyenne_6M  \
# 0                 48.057303                   28.811906
# 1                 12.027955                   -8.664351
#
#    Montant_flux_crediteur_M  Montant_pret_banque  Output
# 0               5757.583993          124370.2918    FAUX
# 1               2825.730247          130015.4600    FAUX
#
# [2 rows x 21 columns]

# %%
def concat_df_encours(df,encours):
    """On sépare df en deux parties, encours_credit étant la 6 colonne de df"""
    part1 = df.iloc[:,:5]
    part2 = df.iloc[:,6:]
    df1 = pd.concat([part1,encours],axis=1)
    df1 = pd.concat([df1,part2],axis=1)
    return(df1)

# %%
df1 = concat_df_encours(df,encours)

# %%
df1.head()
# Out:
#      ID  Nombres_adultes  Nombre_personnes_foyer  Age_2eme_personne  \
# 0  2911         2.057430                2.070880          91.042848
# 1  1398         2.060715                2.193722          90.715413
# 2  1793         1.930472                1.946847          90.588554
# 3  1193         1.963631                1.916677          89.300012
# 4  1342         2.009754                2.019892          87.706161
#
#    Note_credit  Encours_credit_bool  Encours_credit_value  \
# 0     0.177448                  1.0           4715.498190
# 1    -0.062708                  1.0           6584.320922
# 2    -0.094438                  1.0          -7792.256696
# 3    -0.286729                  1.0           6118.791869
# 4     0.284325                  1.0          -4266.843489
#
#                                       ID_PP  Encours_credit_habitat  \
# 0  732f2de9240c404122f8c97b952c4cb8be8ede7f             2772.907651
# 1  1cc77d640ec2c383bef7099ff331d2ae962fd712             7094.588072
# 2  34d7809e534d6e7d83e1439cd4032201386fe9dd            -7613.883523
# 3  1539c6f04d9403928ef4e5b662490bd4787ad71d             5874.214001
# 4  27524f055875f70d102006ee6dcb360e982c4a69            -4459.202674
#
#    Montant_flux_crediteur_M1  ...  Nombre_retrait_carte_M1  \
# 0                9005.374276  ...                 0.160537
# 1                5047.824214  ...                -0.172851
# 2                -692.852208  ...                -0.037880
# 3                1408.588664  ...                 0.994902
# 4                -889.296675  ...                -0.027045
#
#    Nombre_retrait_carte_M1,1  Quantité_obligations  Nombre_connexion_appli_6M  \
# 0                   0.094456          262736.76140                  46.683372
# 1                  -0.170338          157962.64670                   6.806368
# 2                  -0.086625          -26034.01144                   3.442761
# 3                   0.001148          336491.25330                  -6.298359
# 4                   0.080714          -10631.26532                   3.056277
#
#    Nombre_de_connexion_appli_semaine_6M  Nombre_connexion_site_6M  \
# 0                             41.184480                 48.057303
# 1                              9.210575                 12.027955
# 2                              4.988904                  7.072354
# 3                             -7.873857                 -9.758806
# 4                              4.414500                  5.862660
#
#    Duree_connexion_moyenne_6M Montant_flux_crediteur_M  Montant_pret_banque  \
# 0                   28.811906              5757.583993          124370.2918
# 1                   -8.664351              2825.730247          130015.4600
# 2                  -21.135796              1679.601033          130904.7126
# 3                   -6.232009              4059.963478          123729.3778
# 4                  -28.520162              1719.696619          126770.7544
#
#    Output
# 0    FAUX
# 1    FAUX
# 2    FAUX
# 3    FAUX
# 4    FAUX
#
# [5 rows x 28 columns]

# %% [markdown]
# **[Modification de encours credit]**
# > A l'issue de cette première partie nous avons pu retravailler le dataframe et notamment la colonne "Encours_credit" afin de simplifier l'analyse

# %% [markdown]
# ## 1.2 - Répartition des données et outliers
#
# ##### Maintenant que nous avons pu charger correctement le dataset, il faut regarder s'il y a des anomalies dans le jeu de données

# %%
df = df1
df.describe()
# Out:
#                 ID  Nombres_adultes  Nombre_personnes_foyer  \
# count  3015.000000      3005.000000             3006.000000
# mean   1505.492206         1.651430                2.139211
# std     869.645684         3.073339                1.130802
# min       0.000000       -45.154000                0.628834
# 25%     752.500000         1.023015                1.099215
# 50%    1506.000000         1.958080                1.979002
# 75%    2259.500000         2.011098                2.634577
# max    2999.000000       157.000000                8.029462
#
#        Age_2eme_personne  Note_credit  Encours_credit_bool  \
# count       3.013000e+03  3010.000000          2993.000000
# mean        2.247984e+03     4.087619             0.992315
# std         7.714272e+04     3.901568             0.087339
# min        -1.014041e+01    -1.243272             0.000000
# 25%         1.193945e+00     0.060387             1.000000
# 50%         3.295269e+01     6.071823             1.000000
# 75%         4.842538e+01     6.646759             1.000000
# max         3.651695e+06    14.147356             1.000000
#
#        Encours_credit_value  Encours_credit_habitat  \
# count           2970.000000             3011.000000
# mean           67733.356217            66183.088854
# std            97274.363255            97054.712799
# min           -35268.964050           -35446.980780
# 25%              -49.319006            -1058.635777
# 50%            15300.678100            12956.683190
# 75%           122237.835025           121627.982600
# max           779946.571100           779588.699300
#
#        Montant_flux_crediteur_M1  Montant_obligations  ...  \
# count                3011.000000         3.011000e+03  ...
# mean                 3430.032454         1.057915e+04  ...
# std                 12601.220620         3.639671e+04  ...
# min                -12073.545780        -1.111274e+04  ...
# 25%                  -355.231937         1.663585e+02  ...
# 50%                  2173.796979         4.705268e+03  ...
# 75%                  5120.094253         9.941821e+03  ...
# max                397248.044000         1.003670e+06  ...
#
#        Montant_retrait_carte_M1  Nombre_retrait_carte_M1  \
# count               3008.000000              3011.000000
# mean                  25.181340                 0.141723
# std                  127.211080                 0.815417
# min                  -61.640257                -0.276593
# 25%                   -8.283941                -0.045147
# 50%                    1.666568                 0.010977
# 75%                   12.740980                 0.066336
# max                 2406.320620                17.061262
#
#        Nombre_retrait_carte_M1,1  Quantité_obligations  \
# count                3010.000000          3.009000e+03
# mean                    0.150699          1.941102e+05
# std                     0.976184          2.198428e+06
# min                    -0.287192         -5.665139e+05
# 25%                    -0.050422         -4.443938e+04
# 50%                     0.006696          7.685730e+04
# 75%                     0.073643          2.001135e+05
# max                    23.098115          1.001995e+08
#
#        Nombre_connexion_appli_6M  Nombre_de_connexion_appli_semaine_6M  \
# count                2994.000000                           2994.000000
# mean                   21.343223                             26.634469
# std                    42.840104                             57.345026
# min                   -12.976680                            -15.128918
# 25%                     0.940546                              1.122001
# 50%                     6.721483                              8.460031
# 75%                    23.635741                             29.717792
# max                   786.034686                           1271.847271
#
#        Nombre_connexion_site_6M  Duree_connexion_moyenne_6M  \
# count               2996.000000                 3006.000000
# mean                  33.320717                  102.902545
# std                   74.547646                  151.341643
# min                  -19.493009                  -43.124721
# 25%                    1.411483                    7.331611
# 50%                   10.834154                   57.338650
# 75%                   36.966530                  150.928176
# max                 1731.175163                 2085.949319
#
#        Montant_flux_crediteur_M  Montant_pret_banque
# count               3009.000000           3008.00000
# mean                4069.769709         129798.31574
# std                17200.093454          50784.99592
# min                -5509.113441         -12165.56655
# 25%                  494.447401         124794.80720
# 50%                 1963.882364         129489.98350
# 75%                 3801.005236         134389.96840
# max               367964.823600         722428.89020
#
# [8 rows x 25 columns]

# %% [markdown]
# #### Analyse skewness & kurtosis
#
# Le but est d'analyser la répartition et la symétrie des données pour voir si il y a des outliers

# %%
df.skew()
#df.kurtosis()
# Out:
# ID                                      -0.003092
# Nombres_adultes                         41.276719
# Nombre_personnes_foyer                   1.183082
# Age_2eme_personne                       40.209588
# Note_credit                              0.346819
# Encours_credit_bool                    -11.281211
# Encours_credit_value                     1.749415
# Encours_credit_habitat                   1.735483
# Montant_flux_crediteur_M1               18.673586
# Montant_obligations                     12.031500
# Montant_operation_crediteur_DAV_M1       9.193942
# Montant_operation_crediteur_DAV_M       10.888899
# Montant_operation_debiteur_DAV_M1        9.139366
# Montant_operation_debiteur_DAV_M         6.699842
# Montant_retrait_carte_M                  6.679253
# Montant_retrait_carte_M1                 7.778168
# Nombre_retrait_carte_M1                 12.031966
# Nombre_retrait_carte_M1,1               14.905489
# Quantité_obligations                    36.016058
# Nombre_connexion_appli_6M                6.132051
# Nombre_de_connexion_appli_semaine_6M     8.770223
# Nombre_connexion_site_6M                 9.775507
# Duree_connexion_moyenne_6M               3.990665
# Montant_flux_crediteur_M                15.578881
# Montant_pret_banque                      2.311561
# dtype: float64

# %% [markdown]
# **Afin de se familiariser avec le dataset nous allons afficher chacune des composantes**

# %%
def plot_skew_kurt(df):
    subplot_pos =[121,122] ## Subplot 2 par ligne
    legends =['',''] # Pour stocker la legende de chaque plot de la ligne
    for (i,cols) in enumerate(df.skew().index[1:]):
        ## Selection de toutes les features sauf ID
        plt.subplot(subplot_pos[i%2])
        legend = f'{cols} - sk : {round(df.skew().values[i+1])} - kurt :{round(df.kurtosis().values[i+1])}'
        legends[i%2] = legend 
        plt.scatter(df.index,df[cols])
        if i%2==0: ## Fin de ligne on affiche
            print('  | '.join(legends))
            plt.subplots_adjust(right = 2)
            plt.show()

# %%
plot_skew_kurt(df) # Scatter plot de la variable & affichage sa skewness et de son kurtosis
# Out:
# Nombres_adultes - sk : 41.0 - kurt :2199.0  |
# Age_2eme_personne - sk : 40.0 - kurt :1762.0  | Nombre_personnes_foyer - sk : 1.0 - kurt :1.0
# Encours_credit_bool - sk : -11.0 - kurt :125.0  | Note_credit - sk : 0.0 - kurt :-1.0
# Encours_credit_habitat - sk : 2.0 - kurt :4.0  | Encours_credit_value - sk : 2.0 - kurt :4.0
# Montant_obligations - sk : 12.0 - kurt :236.0  | Montant_flux_crediteur_M1 - sk : 19.0 - kurt :483.0
# Montant_operation_crediteur_DAV_M - sk : 11.0 - kurt :170.0  | Montant_operation_crediteur_DAV_M1 - sk : 9.0 - kurt :97.0
# Montant_operation_debiteur_DAV_M - sk : 7.0 - kurt :52.0  | Montant_operation_debiteur_DAV_M1 - sk : 9.0 - kurt :95.0
# Montant_retrait_carte_M1 - sk : 8.0 - kurt :83.0  | Montant_retrait_carte_M - sk : 7.0 - kurt :53.0
# Nombre_retrait_carte_M1,1 - sk : 15.0 - kurt :293.0  | Nombre_retrait_carte_M1 - sk : 12.0 - kurt :201.0
# Nombre_connexion_appli_6M - sk : 6.0 - kurt :76.0  | Quantité_obligations - sk : 36.0 - kurt :1508.0
# Nombre_connexion_site_6M - sk : 10.0 - kurt :184.0  | Nombre_de_connexion_appli_semaine_6M - sk : 9.0 - kurt :154.0
# Montant_flux_crediteur_M - sk : 16.0 - kurt :287.0  | Duree_connexion_moyenne_6M - sk : 4.0 - kurt :31.0

# %% [markdown]
# ### Enlever les outliers
# On remarque que **3 features** ont un **kurtosis & une skewness très élevé** - le plot confirme la présence d'**outliers**:
#
# **Pour ces deux features, il est nécessaire de se séparer de tous les outliers, car elles n'ont pas de sens, par exemple : <br>max(Nombres_adultes) = 157**
#
# * Nombres_adultes
# * Age_2e_personne
#
# **Pour cette feature, on va uniquement enlever le maximum (1 000 000)**
# * Quantités_obligations

# %% [markdown]
# ### Filtrer les outliers

# %%
"""Avec les paramètres suivants on peut : 
Enlever les outliers pour Nombres_adultes  >25 ou <0 (pas de nombre_adultes négatif)
Enlever les outliers au niveau de l'âge : >200
Quantité d'obligations : On enlève le max qui déforme le dataset et est beaucoup trop éloigné des autres valeurs
"""

outliers_filters = (df.Nombres_adultes>25)|(df.Nombres_adultes<0)|(df.Age_2eme_personne>200)|(df.Quantité_obligations==max(df.Quantité_obligations))

# %%
"""Voici les données que nous allons enlever du dataset"""
df[outliers_filters]
# Out:
#        ID  Nombres_adultes  Nombre_personnes_foyer  Age_2eme_personne  \
# 13   1125         1.988612                1.996277       1.500000e+06
# 20   2436       157.000000                2.207566       8.286753e+01
# 23     30         1.998692                1.870891       1.534521e+06
# 38   2763       -35.000000                1.833692       7.956678e+01
# 45   2311       -45.154000                1.980447       7.860640e+01
# 90    390         1.927201                1.774959       3.651695e+06
# 164   808         2.037934                1.984801       6.773047e+01
#
#      Note_credit  Encours_credit_bool  Encours_credit_value  \
# 13      0.468081                  1.0           5286.493638
# 20      0.124294                  1.0          -8047.237148
# 23     -0.327990                  1.0          -2517.344670
# 38      0.164459                  1.0          -9726.573835
# 45     -0.224071                  1.0          -1361.812353
# 90     -0.462633                  1.0          -4117.758621
# 164    -0.120481                  1.0          -3012.301219
#
#                                         ID_PP  Encours_credit_habitat  \
# 13   dc5c0440a9a7fa6e56ef9c41ec30044dfc6aafe2             3887.092790
# 20   b9da2f10fa9da8a341c9270d22825508bb01c3aa            -7553.047311
# 23   c368cc66aff85ee21a1a90964c611b23d15a2e12            -2604.063097
# 38   ddbf56d6a375013d611d93a608c862af27f376d0           -10332.358050
# 45   00c496dc805e6d74d21b803aaf0d5b3334faa349            -1421.340490
# 90   01e45b8e536995696fd685d6e1f49bfc819168d4            -3146.248259
# 164  aca550f13c3627508b776a1b5a8a8876e65b04d7            -2753.502799
#
#      Montant_flux_crediteur_M1  ...  Nombre_retrait_carte_M1  \
# 13                 -728.100980  ...                 1.030981
# 20                 2303.188415  ...                 0.028504
# 23                 2827.502265  ...                -0.009947
# 38                 -795.964305  ...                -0.039791
# 45                  653.830813  ...                 0.934992
# 90                -1242.853205  ...                 0.107656
# 164                8897.974922  ...                 0.019288
#
#      Nombre_retrait_carte_M1,1  Quantité_obligations  \
# 13                    1.119442          1.315948e+06
# 20                    0.012999         -6.527436e+04
# 23                   -0.028837          1.891141e+06
# 38                   -0.034498          9.370660e+04
# 45                    2.930379          7.564783e+04
# 90                    0.052591          1.136401e+05
# 164                   0.008760          1.001995e+08
#
#      Nombre_connexion_appli_6M  Nombre_de_connexion_appli_semaine_6M  \
# 13                   -1.117414                             -0.988967
# 20                   -6.175580                             -5.440543
# 23                   93.231513                             80.120497
# 38                    2.489446                              0.090541
# 45                    3.631247                              4.646773
# 90                   29.385684                             28.240021
# 164                  89.816645                             80.038331
#
#      Nombre_connexion_site_6M  Duree_connexion_moyenne_6M  \
# 13                  -0.885137                  -21.857154
# 20                  -6.487811                    3.370448
# 23                 100.353803                  268.078651
# 38                  -0.143907                  -13.595050
# 45                   4.737960                   17.970802
# 90                  31.809899                  -18.751434
# 164                112.270599                  374.607394
#
#     Montant_flux_crediteur_M  Montant_pret_banque  Output
# 13               3629.066274          123788.7548    FAUX
# 20               1632.176481          129916.1813    VRAI
# 23               4517.537171          136168.2920    FAUX
# 38               1542.499101          129448.9522    FAUX
# 45               4789.286357          135816.6949    FAUX
# 90               1116.904916          129835.9530    FAUX
# 164             22950.805510          113190.3472    VRAI
#
# [7 rows x 28 columns]

# %%
outliers_index = df[outliers_filters].index #On garde les index des outliers

# %%
df1 = df.copy()

# %%
df1 = df[~df.index.isin(outliers_index)].reset_index(drop=True) # On met les outliers de côtés

# %% [markdown]
# ### Après avoir filtré les outliers -  Nouvelle analyse skewness & kurtosis

# %%
df1.shape
# Out:
# (3008, 28)

# %%
df.shape
# Out:
# (3015, 28)

# %%
df1.describe()
# Out:
#                 ID  Nombres_adultes  Nombre_personnes_foyer  \
# count  3008.000000      2998.000000             2999.000000
# mean   1505.716755         1.627001                2.139653
# std     869.290959         0.484844                1.132066
# min       0.000000         0.869316                0.628834
# 25%     752.750000         1.023053                1.098764
# 50%    1506.500000         1.958061                1.978972
# 75%    2258.250000         2.011032                2.744282
# max    2999.000000         3.006550                8.029462
#
#        Age_2eme_personne  Note_credit  Encours_credit_bool  \
# count        3006.000000  3003.000000          2986.000000
# mean           28.825561     4.097274             0.992297
# std            24.892164     3.900953             0.087441
# min           -10.140412    -1.243272             0.000000
# 25%             1.184886     0.061701             1.000000
# 50%            32.919935     6.073068             1.000000
# 75%            48.332106     6.651442             1.000000
# max            91.042848    14.147356             1.000000
#
#        Encours_credit_value  Encours_credit_habitat  \
# count           2963.000000             3004.000000
# mean           67901.304252            66345.274303
# std            97327.508262            97109.294226
# min           -35268.964050           -35446.980780
# 25%               61.072253             -909.148867
# 50%            15415.914820            13019.576045
# 75%           122706.730700           121855.129975
# max           779946.571100           779588.699300
#
#        Montant_flux_crediteur_M1  Montant_obligations  ...  \
# count                3004.000000          3004.000000  ...
# mean                 3434.058636         10129.304273  ...
# std                 12614.628178         31365.482404  ...
# min                -12073.545780        -11112.742260  ...
# 25%                  -352.258920           160.153010  ...
# 50%                  2175.508736          4688.742024  ...
# 75%                  5122.783487          9931.201318  ...
# max                397248.044000        565896.779800  ...
#
#        Montant_retrait_carte_M1  Nombre_retrait_carte_M1  \
# count               3001.000000              3004.000000
# mean                  25.102147                 0.141363
# std                  127.143296                 0.816060
# min                  -61.640257                -0.276593
# 25%                   -8.255494                -0.045272
# 50%                    1.667738                 0.010836
# 75%                   12.734430                 0.066320
# max                 2406.320620                17.061262
#
#        Nombre_retrait_carte_M1,1  Quantité_obligations  \
# count                3003.000000          3.002000e+03
# mean                    0.149698          1.600444e+05
# std                     0.975823          1.228497e+06
# min                    -0.287192         -5.665139e+05
# 25%                    -0.050706         -4.461642e+04
# 50%                     0.006588          7.683218e+04
# 75%                     0.073626          1.997422e+05
# max                    23.098115          4.163348e+07
#
#        Nombre_connexion_appli_6M  Nombre_de_connexion_appli_semaine_6M  \
# count                2987.000000                           2987.000000
# mean                   21.322513                             26.634380
# std                    42.843987                             57.386837
# min                   -12.976680                            -15.128918
# 25%                     0.941826                              1.125489
# 50%                     6.726718                              8.460611
# 75%                    23.594110                             29.699475
# max                   786.034686                           1271.847271
#
#        Nombre_connexion_site_6M  Duree_connexion_moyenne_6M  \
# count               2989.000000                 2999.000000
# mean                  33.317904                  102.939389
# std                   74.600335                  151.339618
# min                  -19.493009                  -43.124721
# 25%                    1.417528                    7.422034
# 50%                   10.838098                   57.417767
# 75%                   36.884775                  150.901409
# max                 1731.175163                 2085.949319
#
#        Montant_flux_crediteur_M  Montant_pret_banque
# count               3002.000000          3001.000000
# mean                4065.875676        129801.788927
# std                17216.479346         50842.935701
# min                -5509.113441        -12165.566550
# 25%                  491.620936        124798.290300
# 50%                 1963.766421        129486.913900
# 75%                 3796.772909        134389.615800
# max               367964.823600        722428.890200
#
# [8 rows x 25 columns]

# %%
df1.skew()
# Out:
# ID                                      -0.003028
# Nombres_adultes                         -0.505495
# Nombre_personnes_foyer                   1.180729
# Age_2eme_personne                        0.112854
# Note_credit                              0.343199
# Encours_credit_bool                    -11.267715
# Encours_credit_value                     1.746434
# Encours_credit_habitat                   1.732454
# Montant_flux_crediteur_M1               18.656586
# Montant_obligations                      8.234687
# Montant_operation_crediteur_DAV_M1       9.188814
# Montant_operation_crediteur_DAV_M       10.934636
# Montant_operation_debiteur_DAV_M1        9.183713
# Montant_operation_debiteur_DAV_M         6.607157
# Montant_retrait_carte_M                  6.697234
# Montant_retrait_carte_M1                 7.800375
# Nombre_retrait_carte_M1                 12.032151
# Nombre_retrait_carte_M1,1               14.951891
# Quantité_obligations                    27.089111
# Nombre_connexion_appli_6M                6.143452
# Nombre_de_connexion_appli_semaine_6M     8.771208
# Nombre_connexion_site_6M                 9.777282
# Duree_connexion_moyenne_6M               3.997720
# Montant_flux_crediteur_M                15.570943
# Montant_pret_banque                      2.308852
# dtype: float64

# %%
plot_skew_kurt(df1)
# Out:
# Nombres_adultes - sk : -1.0 - kurt :-2.0  |
# Age_2eme_personne - sk : 0.0 - kurt :-1.0  | Nombre_personnes_foyer - sk : 1.0 - kurt :1.0
# Encours_credit_bool - sk : -11.0 - kurt :125.0  | Note_credit - sk : 0.0 - kurt :-1.0
# Encours_credit_habitat - sk : 2.0 - kurt :4.0  | Encours_credit_value - sk : 2.0 - kurt :4.0
# Montant_obligations - sk : 8.0 - kurt :95.0  | Montant_flux_crediteur_M1 - sk : 19.0 - kurt :482.0
# Montant_operation_crediteur_DAV_M - sk : 11.0 - kurt :172.0  | Montant_operation_crediteur_DAV_M1 - sk : 9.0 - kurt :97.0
# Montant_operation_debiteur_DAV_M - sk : 7.0 - kurt :51.0  | Montant_operation_debiteur_DAV_M1 - sk : 9.0 - kurt :97.0
# Montant_retrait_carte_M1 - sk : 8.0 - kurt :83.0  | Montant_retrait_carte_M - sk : 7.0 - kurt :53.0
# Nombre_retrait_carte_M1,1 - sk : 15.0 - kurt :294.0  | Nombre_retrait_carte_M1 - sk : 12.0 - kurt :201.0
# Nombre_connexion_appli_6M - sk : 6.0 - kurt :76.0  | Quantité_obligations - sk : 27.0 - kurt :873.0
# Nombre_connexion_site_6M - sk : 10.0 - kurt :184.0  | Nombre_de_connexion_appli_semaine_6M - sk : 9.0 - kurt :154.0
# Montant_flux_crediteur_M - sk : 16.0 - kurt :287.0  | Duree_connexion_moyenne_6M - sk : 4.0 - kurt :31.0

# %% [markdown]
# **Nous obtenons des résultats beaucoup plus cohérents pour les variables auxquelles ont a enlevé les outliers** <br>
#
#
#
# ### Quelques remarques sur le dataset
#
# **Concernant nombres_adultes & age_2eme_personne :**
#
# On peut remarquer 2 profils :
#
# * Nb Adultes = 2 & Age_2eme personne $\in$ [20:80] :
#     * Couple
# * Nb Adultes = 1 & Age_2eme personne $\in$ [0:10] :
#     * Famille monoparentale

# %% [markdown]
# ## 1.3 - Encodage CSP
#
# Il nous reste maintenant à encoder la colonne CSP, qui nous indique si la catégorie socio-professionelle des personnes étudiées.
# * CSP+ : Cat Socio Professionelle "Supérieure"
# * CSP-: Cat Socio Professionelle "Inférieure"

# %%
df1.CSP[:5]
# Out:
# 0    CSP+
# 1    CSP-
# 2    CSP+
# 3    CSP-
# 4    CSP+
# Name: CSP, dtype: object

# %% [markdown]
# Pour ce faire nous allons renommer la colonne CSP -> CSP+ :
#
# * 1 - Si CSP +
# * 0 - Si CSP -

# %%
csp_dict = {'CSP+':1,'CSP-':0,np.nan:np.nan} # Utilisation d'un dictionnaire pour un encodage rapide

df1['CSP'] = [csp_dict[csp_i]  for csp_i in df1['CSP']]

# %% [markdown]
# ## 1.4 - Transformation Output
#
# Comme nous avons pu le voir, output est un booléen en français qu'il faut donc transformer en anglais :
#
# * VRAI -> TRUE
# * FAUX -> FALSE

# %%
df1.Output[:5]
# Out:
# 0    FAUX
# 1    FAUX
# 2    FAUX
# 3    FAUX
# 4    FAUX
# Name: Output, dtype: object

# %%
output_dict = {'FAUX':False,'VRAI':True,np.nan:np.nan}

# %%
df1['Output'] = [output_dict[output] for output in df1['Output']]

# %% [markdown]
# # 2. Analyse des données
#
# Maintenant que nous avons chargé le dataset et reformaté les données qui se devaient d'être reformatées, nous allons pouvoir regarder :
# * Les features, valeurs, répartitions
# * Output, répartitions

# %% [markdown]
# ## 2.1 Analyse des features & output

# %%
df = df1.copy() # On sauvegarde sur df les changements réalisés précedemment

# %% [markdown]
# ### Analyse des features

# %%
df.columns
# Out:
# Index(['ID', 'Nombres_adultes', 'Nombre_personnes_foyer', 'Age_2eme_personne',
#        'Note_credit', 'Encours_credit_bool', 'Encours_credit_value', 'ID_PP',
#        'Encours_credit_habitat', 'Montant_flux_crediteur_M1',
#        'Montant_obligations', 'Montant_operation_crediteur_DAV_M1',
#        'Montant_operation_crediteur_DAV_M',
#        'Montant_operation_debiteur_DAV_M1', 'Montant_operation_debiteur_DAV_M',
#        'Montant_retrait_carte_M', 'Montant_retrait_carte_M1', 'CSP',
#        'Nombre_retrait_carte_M1', 'Nombre_retrait_carte_M1,1',
#        'Quantité_obligations', 'Nombre_connexion_appli_6M',
#        'Nombre_de_connexion_appli_semaine_6M', 'Nombre_connexion_site_6M',
#        'Duree_connexion_moyenne_6M', 'Montant_flux_crediteur_M',
#        'Montant_pret_banque', 'Output'],
#       dtype='object')

# %% [markdown]
# ### Des "catégories dans les features" :
#
# > On remarque que l'on peut classer les features selon leurs appartenances aux catégories suivantes
#
# | Catégories | Informations globales <br> (Informations concernant la personne, age, nbr adultes, montant du crédit, crédit restant) | Opérations bancaires <br> (Ensemble des opérations effectuées sur le mois) | Extra financiers <br> (Informations sur le comportement de la personne, suivi de ses opérations bancaire) |
# | ---------- | ------------------------------------------------------------ | ------------------------------------------------------------ | ------------------------------------------------------------ |
# | Features   | Nombre_adultes \| Nombre_personnes_foyer <br> Age_2e_personne \| Note_credit \| Montant_pret_banque <br> CSP ; Encours | Montant_operation_crediteur/debiteur <br> Nombre de retraits <br> Montant_flux_créditeur | Nombre_connexion_appli <br> Nombre_connexion_site <br> Durée de connexion moyenne |
#
# **En regroupant selon ces catégories, l'analyse de corrélation sera plus pertinente**

# %%
### On construit ces catégories en accord avec le tableau ci-dessus
infos_globales_cols = ['Nombres_adultes', 'CSP','Nombre_personnes_foyer', 'Age_2eme_personne',
       'Note_credit', 'Encours_credit_bool', 'Encours_credit_value',
       'Encours_credit_habitat','Montant_pret_banque']
operations_bancaires_cols = ['Montant_flux_crediteur_M1',
       'Montant_obligations', 'Montant_operation_crediteur_DAV_M1',
       'Montant_operation_crediteur_DAV_M',
       'Montant_operation_debiteur_DAV_M1', 'Montant_operation_debiteur_DAV_M',
       'Montant_retrait_carte_M', 'Montant_retrait_carte_M1',
       'Nombre_retrait_carte_M1', 'Nombre_retrait_carte_M1,1','Montant_flux_crediteur_M','Quantité_obligations']
extra_financiers_cols = ['Nombre_connexion_appli_6M',
       'Nombre_de_connexion_appli_semaine_6M', 'Nombre_connexion_site_6M',
       'Duree_connexion_moyenne_6M']
"""Reorganisation des features_cols"""
features_cols = infos_globales_cols+operations_bancaires_cols+extra_financiers_cols

# %%
features = df[features_cols]

# %%
plt.figure(figsize=(16,6))
sns.heatmap(features.corr(),vmin=-1,vmax=1,annot=True)
plt.show()

# %% [markdown]
# **Matrice de corrélation**
#
# Ce regroupement par catégories nous permet d'identifier des matrices dans la matrice de corrélation : ce qui traduit le lien entre certaines variables d'une même catégorie.<br>
# Certaines catégories sont (faiblement) corrélées entre elles : <br>
# * Informations globales -- Opérations globales

# %% [markdown]
# ## Analyse de [Output]

# %% [markdown]
# ### Répartition globale

# %%
df.groupby('Output').count()
# Out:
#           ID  Nombres_adultes  Nombre_personnes_foyer  Age_2eme_personne  \
# Output
# False   2167             2159                    2161               2166
# True     833              831                     830                832
#
#         Note_credit  Encours_credit_bool  Encours_credit_value  ID_PP  \
# Output
# False          2165                 2150                  2133   2161
# True            830                  829                   823    832
#
#         Encours_credit_habitat  Montant_flux_crediteur_M1  ...   CSP  \
# Output                                                     ...
# False                     2165                       2164  ...  2164
# True                       831                        832  ...   831
#
#         Nombre_retrait_carte_M1  Nombre_retrait_carte_M1,1  \
# Output
# False                      2163                       2164
# True                        833                        831
#
#         Quantité_obligations  Nombre_connexion_appli_6M  \
# Output
# False                   2165                       2152
# True                     829                        827
#
#         Nombre_de_connexion_appli_semaine_6M  Nombre_connexion_site_6M  \
# Output
# False                                   2149                      2151
# True                                     830                       830
#
#         Duree_connexion_moyenne_6M  Montant_flux_crediteur_M  \
# Output
# False                         2160                      2162
# True                           832                       832
#
#         Montant_pret_banque
# Output
# False                  2162
# True                    832
#
# [2 rows x 27 columns]

# %% [markdown]
# #### On observe que Output est déséquilibré :
# * 2/3 - 1/3 : False // True
#
# #### Il faudra donc avoir recours à de la cross validation afin d'estimer au mieux la qualité de notre modèle
# <br>
#
# ### Sens output & lien avec les variables
#
# **Les variables** : Comme nous l'avons vu précédemment, il est possible de regrouper les variables par catégories et celles-ci donnent des informations sur 3 composantes
# * *Informations globales* : Profil du client
# * *Information bancaires* : Opérations réalisées par le client
# * *Information Extra-financières* : Assuidité, suivi des comptes bancaires
#
# **Output** :
#
# Cette variable à prédire prend deux valeurs : *VRAI* ou *FAUX* :
# <br>
# Au vu des variables endogènes on peut supposer les choses suivantes sur Output :
#
# * Output peut caractériser le fait que le client en question soit en défaut de paiement sur son prêt
#     * Applications : Eviter de prêter de l'argent à des gens à risque
#
# * Output peut caractériser le fait que le client en question soit au contraire un "bon client" ou non
#     * Appplications : Identifier plus facilement les bons profils
#
# > Afin de mieux comprendre le sens de cette variable nous allons procéder à une exploration "simple" avec des regroupements en fonction de certaines variables

# %%
from sklearn.preprocessing import MinMaxScaler
def groupby_output(df,cols,plot=True):
    """Permet de renvoyer la moyenne des variables pour chaque types de variables"""
    all_cols = cols +['Output']
    """Affichage des données (scale pour pouvoir tout afficher sur le même graphe)"""
    # Premier Df qui permet de mener une analyse qualitative en ayant le sens sur les variables
    df1 = df[all_cols].groupby('Output').mean()
    # Scale df et analyser le groupby
    X = df[cols].values
    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)
    df_scaled = pd.concat([pd.DataFrame(X,columns=cols),pd.DataFrame(df['Output'])],axis=1)
    # Group df_scaled
    df2 = df_scaled[all_cols].groupby('Output').mean()
    scaled_cols = df2.columns
    if plot:
        df2.plot.bar()
        plt.legend(bbox_to_anchor=(2,0.5),loc='center right')
        plt.show()
    return(df1)

# %% [markdown]
# ## Output & Informations globales

# %%
infos_output = groupby_output(df,infos_globales_cols)
# groupby_output(infos_globales_cols)
infos_output
# Out:
#         Nombres_adultes       CSP  Nombre_personnes_foyer  Age_2eme_personne  \
# Output
# False          1.533727  0.506007                1.982359          24.430347
# True           1.869312  0.519856                2.551882          40.206963
#
#         Note_credit  Encours_credit_bool  Encours_credit_value  \
# Output
# False      3.698490             0.992093          54909.235507
# True       5.163276             0.992762         102163.162792
#
#         Encours_credit_habitat  Montant_pret_banque
# Output
# False             53749.468068        127473.837470
# True              99818.213237        135858.672833

# %% [markdown]
# ### Lien entre informations globales et output
#
# **On observe que lorsque Output est True :**
# * Le profil du client est différent :
#     * Personne en couple (NbAdultes 1.8) ; plus âgé : 40 ans en moyenne
# * La note de crédit est meilleure
# * Le montant de l'encours est plus important <br>
#
# **Et donc à l'inverse lorsque Output est False :**
# * Personne plus jeune, seule, ou famille monoparentale
# * Encours moins important & montant de prêt plus faible
#
# *Influence du paramètre CSP :* La classe Socio Professionnelle ne semble pas être un facteur déterminant

# %%
df.groupby(['Output','CSP']).count()
# Out:
#               ID  Nombres_adultes  Nombre_personnes_foyer  Age_2eme_personne  \
# Output CSP
# False  0.0  1069             1064                    1063               1068
#        1.0  1095             1092                    1095               1095
# True   0.0   399              399                     397                398
#        1.0   432              430                     431                432
#
#             Note_credit  Encours_credit_bool  Encours_credit_value  ID_PP  \
# Output CSP
# False  0.0         1068                 1062                  1052   1067
#        1.0         1094                 1085                  1078   1091
# True   0.0          397                  397                   393    399
#        1.0          431                  431                   429    431
#
#             Encours_credit_habitat  Montant_flux_crediteur_M1  ...  \
# Output CSP                                                     ...
# False  0.0                    1069                       1066  ...
#        1.0                    1093                       1095  ...
# True   0.0                     397                        398  ...
#        1.0                     432                        432  ...
#
#             Montant_retrait_carte_M1  Nombre_retrait_carte_M1  \
# Output CSP
# False  0.0                      1068                     1067
#        1.0                      1091                     1093
# True   0.0                       398                      399
#        1.0                       431                      432
#
#             Nombre_retrait_carte_M1,1  Quantité_obligations  \
# Output CSP
# False  0.0                       1066                  1069
#        1.0                       1095                  1093
# True   0.0                        398                   395
#        1.0                        431                   432
#
#             Nombre_connexion_appli_6M  Nombre_de_connexion_appli_semaine_6M  \
# Output CSP
# False  0.0                       1062                                  1060
#        1.0                       1087                                  1086
# True   0.0                        396                                   396
#        1.0                        429                                   432
#
#             Nombre_connexion_site_6M  Duree_connexion_moyenne_6M  \
# Output CSP
# False  0.0                      1062                        1064
#        1.0                      1087                        1093
# True   0.0                       396                         399
#        1.0                       432                         431
#
#             Montant_flux_crediteur_M  Montant_pret_banque
# Output CSP
# False  0.0                      1067                 1066
#        1.0                      1092                 1093
# True   0.0                       398                  399
#        1.0                       432                  432
#
# [4 rows x 26 columns]

# %% [markdown]
# Je décide donc de ne pas considérer CSP pour les prochaines analyses et pour la modélisation.
# > Je l'avais tout d'abord considéré mais mettre CSP de côté améliore la performance des modèles !

# %%
features_cols.remove('CSP')

# %% [markdown]
# ## Output & Informations bancaires

# %%
bancaires_output = groupby_output(df,operations_bancaires_cols)
# groupby_output(infos_globales_cols)
bancaires_output
# Out:
#         Montant_flux_crediteur_M1  Montant_obligations  \
# Output
# False                 2618.245451         11648.642622
# True                  5580.669150          6229.993193
#
#         Montant_operation_crediteur_DAV_M1  Montant_operation_crediteur_DAV_M  \
# Output
# False                          6572.115729                        3848.981654
# True                          11868.746673                        8786.311920
#
#         Montant_operation_debiteur_DAV_M1  Montant_operation_debiteur_DAV_M  \
# Output
# False                         6257.514256                       7999.454186
# True                         11344.509192                      10501.935343
#
#         Montant_retrait_carte_M  Montant_retrait_carte_M1  \
# Output
# False                 30.690266                 32.447625
# True                   8.258883                  5.931756
#
#         Nombre_retrait_carte_M1  Nombre_retrait_carte_M1,1  \
# Output
# False                  0.183974                   0.193074
# True                   0.031241                   0.037389
#
#         Montant_flux_crediteur_M  Quantité_obligations
# Output
# False                3226.527547         167624.961198
# True                 6253.349011         141311.905701

# %% [markdown]
# ### Lien entre opérations bancaires et output
#
# **On observe que lorsque Output est True :**
# * Les montants des flux créditeurs sont plus importants :
#     * Ce qui traduit des revenus plus elevés
# * Les montants des obligations sont plus faible
#
# **Et donc à l'inverse lorsque Output est False :**
# * Flux créditeurs moins importants
# * Nombre de retraits en cartes plus importants
#
#
# ### Evolution de certaines variables
# Il est intéressant de regarder l'évolution de certaines variables :
# * Montant_flux_créditeur (M(-1)->M)
# * Montant_operation_crediteur_DAV (M(-1)->M)
# * Montant_operation_debiteur_DAV (M(-1)->M)
# * Montant_retrait_carte (M(-1)->M)

# %%
mois = ['M1','M']
base = ['Montant_flux_crediteur_','Montant_operation_crediteur_DAV_','Montant_operation_debiteur_DAV_']
evolution_cols_bancaire = []
"""Construction des colonnes rapides"""
for b in base :
    for m in mois :
        s = b+m
        evolution_cols_bancaire.append(s)

# %%
evolution_bancaires_output = groupby_output(df,evolution_cols_bancaire,plot=False)
evolution_bancaires_output.plot.bar()
plt.legend(bbox_to_anchor=(2,0.5),loc='center right')
plt.show()

# %% [markdown]
# ### Analyse de l'évolution :
#
# > Rq : Je n'ai pas scale les données de ces variables pour le plot afin de pouvoir comparer des variables deux à deux
#
# #### Concernant ces variables :
#
# * Montant_flux_créditeur (M(-1)->M)(Bleu & Orange)
# * Montant_operation_crediteur_DAV (M(-1)->M) (Vert & Rouge)
#
# Peu importe la valeur de l'Output ces variables évoluent de la même façon
# * Montant_flux_créditeur (M(-1)->M)(Bleu & Orange) : **Augmente**
# * Montant_operation_crediteur_DAV (M(-1)->M) (Vert & Rouge) : **Diminution**
#
# #### Concernant cette variable on peut discriminer de façon plus pertinente :
#
# * Montant_operation_debiteur_DAV (M(-1)->M) (Violet & Marron)
#
# | Variable \ Output                     | True  | False    |
# | -------------------------- | ----- | -------- |
# | Montant Opération Débiteur | Diminue | Augmente |
#
# * Baisse au niveau débiteur pour Output = True, augmentation pour Output = False

# %% [markdown]
# ## Output & Informations Extra Financières

# %%
extra_fi_output = groupby_output(df,extra_financiers_cols)
extra_fi_output
# Out:
#         Nombre_connexion_appli_6M  Nombre_de_connexion_appli_semaine_6M  \
# Output
# False                   19.829888                             24.388657
# True                    25.323693                             32.515663
#
#         Nombre_connexion_site_6M  Duree_connexion_moyenne_6M
# Output
# False                  30.629056                   94.637478
# True                   40.371012                  124.751721

# %% [markdown]
# ### Lien entre données extrafinancières et output
#
# **On observe que lorsque Output est True :**
#
# Le client est plus assidu :
# * Le nombre de connexions est plus important, la durée passée sur le site internet est plus importante, et donc le suivi du compte bancaire de meilleure qualité
#
# **Et donc à l'inverse lorsque Output est False :**
#
# Le client est moins attentif à sa santé financière
# * Celui-ci va passer moins de temps sur le site internet et va être moins assidu

# %% [markdown]
# ## Signification d'Output
#
# ### Conclusion :
#
# Au vu du lien entre les opérations bancaires et l'Output, il semble clair que Output fait la distinction entre les clients ayant une bonne santé financière :
# * Moins d'opérations en débit (en proportion), plus d'opérations en crédit (en proportion)
# * Une plus grande stabilité personnelle (au vu des informations globales)
# * Un meilleur suivi de sa situation financière (au vu du lien extrafinancier - informationsglobales)

# %% [markdown]
# # 3. Choix de la modélisation
#
# ## Type d'apprentissage et choix des modèles
#
# #### Apprentissage supervisé
#
# Nous sommes bien ici dans un cas où nous avons des données dont **on connaît la classe d'appartenance**, l'idée étant donc de pouvoir à l'avenir **prédire la classe d'appartenance d'un nouveau client.**
#
# #### Réduire le nombre de variables
#
# Au vu du nombres de variables important (25), il est nécessaire de **réduire le nombre de variables**, afin de limiter l'erreur du modèle. Une **ACP** va nous permettre de garder un nombre réduit de variables qui expliqueront une grande partie de la variance et donc une grande partie du dataset.
#
#
# #### Méthodes d'apprentissage supervisé choisies :
#
# * SVM Classifier
# * Random Forest Classifier
#
#
#
# | Méthodes                | Avantages                                                    | Inconvénients                                                |
# | ----------------------- | ------------------------------------------------------------ | ------------------------------------------------------------ |
# | Random Forest           | 1. Performant sur la classification <br>2. Capable de manipuler un nombre de features important <br>3. Permet d'appréhender des jeux de données non équilibrés | 1. Nécessite une selection précise des hyperparamètres<br>2. "Boîte noire" |
# | Support Vecteur Machine | 1. Permet la séparation des classes  grâce à l'utilisation de noyau<br><br>2. Si la séparation est claire  et <br>donc la marge suffisante. La prédiction est de très bonne qualité. | 1. Nécessite un nombre de variables limité<br>              |
#
# #### Choix des hyperparamètres :
#
# Au vu des deux modèles que nous avons choisis, il sera nécessaire de choisir les **meilleurs hyperparamètres**. Pour cela il faudra mettre en place une **grille d'expérience.**
#
#
#
#
# ## Choix des metrics
#
# Maintenant que nous avons bien compris la signification de l'Output que nous souhaitons prédire, il est pertinent d'envisager le scénario suivant :
#
# * On souhaite construire un modèle qui détecte les "bons" utilisateurs avec la **meilleure précision possible**, tout en sachant que ceux-ci sont sous représentés.
#
# #### Les metrics intéressantes vont être :
#
# * **Accuracy_score** : Quelle est la précision de notre modèle pour prédire les "bons"
# * **Recall** : La fraction des échantillons de la classe qui sont correctement prédits.
# * **f1_score** : Permet d'évaluer la qualité globale de la classification, est calculé à partir du recall et de l'accuracy
#
# #### Evaluation des performances du modèle :
#
# Il est important de garder à l'esprit que notre **jeu de données est fortement déséquilibré**, et qu'il va donc être nécessaire d'avoir recours à la **cross validation pour estimer correctement sa performance.**

# %% [markdown]
# # 4. Analyse en Composante Principale
#
# Au vu du nombre conséquent de variables, il me paraît pertinent de faire une ACP afin de réduire le nombre de variables à utiliser pour le modèle

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Calibrage du dataset
# * X : features
# * y : output

# %%
""" J'utilise un MinMaxScaler qui après analyse permet d'augmenter 
la variance expliquée sur les premieres composantes de l'ACP"""
scaler = MinMaxScaler()

# %% [markdown]
# #### Il faut enlever les NaN du dataframe

# %%
df_without_na = df.dropna()

# %%
print(df_without_na.shape,df.shape,'-- Nombres de lignes en moins:',(df.shape[0]-df_without_na.shape[0]))
# Out:
# (2833, 28) (3008, 28) -- Nombres de lignes en moins: 175

# %% [markdown]
# ### Mise en place de l'ACP

# %%
df_without_na[features_cols].values.shape
# Out:
# (2833, 24)

# %%
def make_pca(df_without_na,features_cols):
    # Chargement des features en array numpy et de l'output
    X = df_without_na[features_cols].values
    y = df_without_na['Output'].tolist()
    scaler = MinMaxScaler()
    # Calibrage de X
    X = scaler.fit_transform(X)
    scaled_df_without_na = pd.DataFrame(X,columns=features_cols)
    # Chargement de l'ACP 
    pca = PCA(random_state=0)
    X = pca.fit_transform(X)
    return(pca,X,y,scaled_df_without_na)

# %%
pca,X,y,scaled_df_without_na = make_pca(df_without_na,features_cols)

# %% [markdown]
# ### Analyse de l'ACP

# %%
def pca_plot(pca,X):
    # Visualisation de l'inertie en fonction du nombres de composantes
    fig,ax = plt.subplots(figsize=(14,5))
    sns.set(font_scale=1)

    plt.step(range(X.shape[1]),pca.explained_variance_ratio_.cumsum(),where='mid', label="Cumulative explained variance")
    sns.barplot(np.arange(1,X.shape[1]+1),pca.explained_variance_ratio_,alpha=0.5, color ="g",label='Individual explained variance')
    plt.xlim(0,10)
    plt.plot((0,10),(0.95,0.95),label='95% inertia')
    ax.set_xticklabels([s for s in ax.get_xticklabels()])

    plt.xlabel('Principal components')
    plt.ylabel('Explained variance')
    plt.legend()
    plt.show()

# %%
pca_plot(pca,X)

# %% [markdown]
# #### On peut garder uniquement les 8 premières composantes qui expliquent quasiment 95% de la variance
#
# ###  Visualisation de l'ACP
#
# ### Construction d'un dataframe avec les 8 premières composantes de l'ACP

# %%
n_components_pca = 8

# %%
def create_ncomponents_df(X,y,n_components_pca=8):
    """Création des colonnes du dataframe"""
    pca_cols = [f'component_{i+1}' for i in range(n_components_pca)]+["Output"]
    principal_components_df = pd.concat([pd.DataFrame(X[:,:n_components_pca]),pd.DataFrame(y)],axis=1)
    principal_components_df.columns = pca_cols
    return(principal_components_df)

# %%
principal_components_df = create_ncomponents_df(X,y)
principal_components_df.head()
# Out:
#    component_1  component_2  component_3  component_4  component_5  \
# 0     0.424057    -0.494354    -0.136317     0.146934     0.006627
# 1     0.419411    -0.508167    -0.119277     0.146933    -0.013520
# 2     0.367902    -0.506387    -0.153280     0.156422     0.000045
# 3     0.367346    -0.517589    -0.139363     0.134887    -0.028180
# 4     0.381369    -0.484162    -0.145638     0.144035     0.001206
#
#    component_6  component_7  component_8  Output
# 0     0.012465     0.050998    -0.042334   False
# 1    -0.016478    -0.006681    -0.062837   False
# 2    -0.006143    -0.010367    -0.069196   False
# 3     0.219480    -0.028046    -0.040031   False
# 4    -0.012210    -0.016539    -0.065866   False

# %% [markdown]
# ### Corrélation entre les variables et les composantes principales

# %%
# Afficher la corrélation entre les variables initiales et les composantes principales
corr_matrix_var_component = pd.concat([scaled_df_without_na,principal_components_df],axis=1).corr()

corr_var_component = corr_matrix_var_component.iloc[len(features_cols):-1,:].transpose().iloc[:len(features_cols),:]

# %%
plt.figure(figsize=(16,6))
sns.heatmap(corr_var_component,vmin=-1,vmax=1,annot=True)
plt.show()

# %% [markdown]
# #### En affichant ces corrélations entre les composantes principales et les variables on retrouve les catégories que nous avions évoquées précédemment et qui sont donc représentées par certaines composantes.

# %% [markdown]
# ### Workflow pca :
# Workflow pour créer la pca avec juste le df sans NaN et les colonnes.

# %%
def workflow_pca(df_without_na,features_cols,n_components_pca=8):
    pca,X,y,scaled_df_without_na = make_pca(df_without_na,features_cols)
    principal_components_df = create_ncomponents_df(X,y,n_components_pca=n_components_pca)
    return(principal_components_df)

# %% [markdown]
# ### Pair plot

# %%
"""Visualisation des plans factoriels de l'ACP"""
sns.pairplot(principal_components_df,hue='Output')
plt.show()

# %% [markdown]
# ##### On constate qu'il n'y a pas de séparations claires entre les deux classes, ce qui laisse présager que le noyau linéaire de notre SVM ne va pas être performant, et qu'il va falloir envisager d'autres noyaux.
# <br>
#
#
#
#
# # 5 - Classification avec un SVC : Support Vector Machine Classifier

# %%
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 5.1. Sélection des features et de Output

# %%
def create_features_principal_comp_df(df):
    X = df.iloc[:,:-1].values
    y = [1 if i else 0 for i in df['Output']]
    y = np.array(y)
    return(X,y)

# %% [markdown]
# ## 5.2. Optimisation des hyperparamètres

# %%
def optimize_svc(X,y):
    """Initialisation du model"""
    svc_model = SVC()
    """Train & Test"""
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=42)
    """Hyperparamètres"""
    search_space = {'kernel':['poly','rbf'],'C':uniform(0,10)}
    """Pas de noyau linéaire au vu des pairs plots mais poly & noyau gaussien"""
    ## Deux noyeaux a l'étude 
    ## 1/C donne la marge de séparation
    """Random Search"""
    svc_random = RandomizedSearchCV(svc_model,search_space, n_jobs=-1, cv = 5,n_iter = 20)
    ## cv = split en 5 parties
    ## Jobs =-1 : Utilisation de tout le processeur
    svc_random.fit(X_train,y_train)
    svc_random.best_params_
    best_svc = svc_random.best_estimator_
    return(best_svc,X_train,y_train)

# %% [markdown]
# ## 5.3. Performance du modèle
#
# Maintenant que nous avons pu choisir les meilleurs paramètres pour notre modèle nous pouvons évaluer sa performance en utilisant la cross validation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
def cross_validation(model,X,y,scoring='accuracy'):
    """k fold-cross validation"""
    model.fit(X,y)
    cv = RepeatedStratifiedKFold(n_splits=5,n_repeats=3,random_state=1)
    scores = cross_val_score(model,X,y,scoring=scoring,cv=cv)
    score = np.mean(scores)
    print(f'{scoring} : {round(score,4)}')
    return(score)

# %% [markdown]
# ### Workflow SVC
# Refaire rapidement PCA + SCV avec le dataframe et les features_cols
# * Création d'un workflow afin de pouvoir tester avec certaines features pour la prochaine partie

# %%
def workflow_svc(df_without_na,features_cols,scoring_metrics = ["accuracy","recall","f1"],n_components_pca=8):
    """PCA"""
    principal_components_df = workflow_pca(df_without_na,features_cols,n_components_pca)
    """Selection des features pour le SVC"""
    X,y = create_features_principal_comp_df(principal_components_df)
    """Optimisation du SVC"""
    best_svc,X_train,y_train = optimize_svc(X,y)
    """Affichage des metrics"""
    scoring_metrics = ["accuracy","recall","f1"]
    best_svc.fit(X_train,y_train)
    scores =[]
    print(f'Voici les métriques du SVC pour les {len(features_cols)} features :\n')
    for scoring in scoring_metrics:
        score = cross_validation(best_svc,X,y,scoring)
        scores.append(score)
    return(scores)

# %%
test_cols =features_cols

# %%
scores_svc = workflow_svc(df_without_na,features_cols)
# Out:
# Voici les métriques du SVC pour les 24 features :
#
# accuracy : 0.7584
# recall : 0.3418
# f1 : 0.4402

# %% [markdown]
# # 6. Classification avec un Random Forest
# ## 6.1. Sélection des features et de output
#
# On utilise la fonction de la section précédente : **create_features_principal_comp_df**
#
# ## 6.2. Optimisation des hyperparamètres

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
def optimize_random_forest(X,y):
    # Nombres d'arbres dans le random forest
    n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1000, num = 10)]
    # Nombre de features ) considérer à chaque split
    max_features = ['auto']
    # Profondeur maximal de chaque arbre
    max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
    max_depth.append(None)
    # Nombre minimum d'échantillons requis pour diviser un nœud
    min_samples_split = [2, 5]
    # Nombre minimum d'échantillons requis à chaque nœud
    min_samples_leaf = [1, 2]
    # Avec ou Sans bootstrap
    bootstrap = [True, False]
    ## Création de la grille
    random_grid = {'n_estimators': n_estimators,
                   'max_features': max_features,
                   'max_depth': max_depth,
                   'min_samples_split': min_samples_split,
                   'min_samples_leaf': min_samples_leaf,
                   'bootstrap': bootstrap}
    ## Creation du modèle
    rfc = RandomForestClassifier()
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=42)
    """De nouveau RandomizedSearchCV"""
    rf_random = RandomizedSearchCV(estimator = rfc, param_distributions = random_grid, n_iter = 10, cv = 3, verbose=2, random_state=42, n_jobs = -1)# Fit the random search model
    rf_random.fit(X_train, y_train)
    best_rf = rf_random.best_estimator_
    return(best_rf,X_train,y_train)

# %% [markdown]
# ## 6.3. Performance du modèle
#
# On utilise la fonction de cross_validation de la section précédente
#
# #### Workflow Random Forest
# * Permet de refaire le Random Forest rapidement pour des features données

# %%
def workflow_random_forest(df_without_na,features_cols,scoring_metrics = ["accuracy","recall","f1"],n_components_pca=8):
    """PCA"""
    principal_components_df = workflow_pca(df_without_na,features_cols,n_components_pca)
    """Selection des features pour le random forest"""
    X,y = create_features_principal_comp_df(principal_components_df)
    """Optimisation du random forest"""
    best_rf,X_train,y_train = optimize_random_forest(X,y)
    """Affichage des metrics"""
    best_rf.fit(X_train,y_train)
    scores = []
    print(f'Voici les métriques du Random Forest pour les {len(features_cols)} features : \n')
    for scoring in scoring_metrics:
        score = cross_validation(best_rf,X,y,scoring)
        scores.append(score)
    return(scores)

# %%
scores_random_forest = workflow_random_forest(df_without_na,features_cols,['accuracy','recall','f1'])
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   24.1s finished
# Voici les métriques du Random Forest pour les 24 features :
#
# accuracy : 0.7639
# recall : 0.4125
# f1 : 0.4928

# %% [markdown]
# ## Comparaison du Random Forest & du SVC
#
# * On observe donc que le Random Forest est plus précis, mais beaucoup plus lent que le SVC
#
# ### La précision est 0.76 ce qui pour le moment n'est pas satisfaisant, il convient donc de revoir notre sélection de features afin d'améliorer nos métriques

# %% [markdown]
# # 7. Amélioration des modèles avec certaines sélections de features
#
# ## Enlever des features pour améliorer la performances
# Enlever certains paramètres comme la catégorie CSP nous a permis d'obtenir de meilleurs résultats :
# * On vérifie cela avec le SVC car celui-ci est plus rapide que le random forest

# %%
csp_cols = features_cols+['CSP']
print('Avec CSP :')
s2=workflow_svc(df_without_na,csp_cols)
print('\nSans CSP :')
s1=workflow_svc(df_without_na,features_cols)
# Out:
# Avec CSP :
# Voici les métriques du SVC pour les 25 features :
#
# accuracy : 0.7407
# recall : 0.1898
# f1 : 0.2898
#
# Sans CSP :
# Voici les métriques du SVC pour les 24 features :
#
# accuracy : 0.7581
# recall : 0.346
# f1 : 0.4431

# %% [markdown]
# ### Quelles autres features peut-on enlever ?
#
# Pour cela nous pouvons raisonner comme la dernière fois sur les catégories de variables :
# * Informations globales
# * Opérations bancaires
# * Informations extra financières
#
# ### Simplifier les informations extra financières
# #### Par rapport à cette dernière catégorie, comme on peut le voir dans l'analyse, une seule variable suffit pour ce groupe
# * Duree_Connexion_6M

# %%
new_features_cols = infos_globales_cols+operations_bancaires_cols+['Duree_connexion_moyenne_6M']
# Enlever CSP
new_features_cols.remove('CSP')

# %%
print('En gardant uniquement la durée de connexion sur 6 mois :')
s2=workflow_svc(df_without_na,new_features_cols)
# Out:
# En gardant uniquement la durée de connexion sur 6 mois :
# Voici les métriques du SVC pour les 21 features :
#
# accuracy : 0.7675
# recall : 0.3637
# f1 : 0.4658

# %%
s2=workflow_random_forest(df_without_na,new_features_cols)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   24.9s finished
# Voici les métriques du Random Forest pour les 21 features :
#
# accuracy : 0.7728
# recall : 0.4264
# f1 : 0.5109

# %% [markdown]
# #### On observe encore une augmentation de l'accuracy, et on retrouve bien le fait qu'il n'est pas pertinent de surcharger son modèle en features !
#
# ### Garder seulement 8 features :
#
# #### Il peut-être intéressant pour finir d'étudier un modèle avec peu de features qui représentent toutes les catégories que nous avons évoquées jusqu'à présent.
#
# On ne va garder que les variables suivantes :
#
# **Informations globales :**
# * Age_2eme_personne
# * Nombres_adultes
# * Nombre_personnes_foyer
# * Encours_credit_habitat
# * Encours_credit_value
#
# **Informations financières :**
# * Montant_operation_crediteur_DAV_M
# * Montant_flux_crediteur_M
#
# **Informations extra-financières :**
# * Duree_connexion_moyenne_6M

# %%
final_features = ['Age_2eme_personne','Nombres_adultes','Nombre_personnes_foyer','Montant_flux_crediteur_M','Encours_credit_habitat','Encours_credit_value','Montant_operation_crediteur_DAV_M','Duree_connexion_moyenne_6M']

# %%
s2=workflow_svc(df_without_na,final_features)
# Out:
# Voici les métriques du SVC pour les 8 features :
#
# accuracy : 0.7619
# recall : 0.3098
# f1 : 0.4204

# %%
s2=workflow_random_forest(df_without_na,final_features)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   25.4s finished
# Voici les métriques du Random Forest pour les 8 features :
#
# accuracy : 0.7712
# recall : 0.4209
# f1 : 0.5057

# %% [markdown]
# #### Avec seulement 8 features on retrouve une précision quasiment équivalente à celle que nous obtenions avec plus du double de features ! Il est donc ici pertinent de simplifier le modèle.

# %% [markdown]
# # Conclusion

# %% [markdown]
# #### Retour sur les données
# Après avoir chargé les données, reformaté quand cela était nécessaire et enlevé les outliers nous avons menés l'analyse du dataset.
#
# Commme nous avons pu le voir lors de cette étude, notre dataset est composé de trois grandes catégories sur les clients :
#
# * Informations globales
# * Informations financières
# * Informations extra-financières
#
# Bien que ces trois catégories soient composées de nombreuses variables, nous avons pu voir qu'il était possible d'extraire uniquement certaines variables afin d'expliquer une catégorie en entier.
#
# L'ACP permet de réduire encore ce nombre de variables et d'obtenir des composantes qui expliquent réellement ces catégories.
#
# #### Classification
# Grâce aux deux modèles de classification SVC et Random Forest nous avons pu mener des prédictions sur la variable Output.
# Pour affiner ces modèles de classification une grande attention a été portée à la sélection des hyperparamètres afin d'obtenir les meilleures prédictions possibles.
#
# Concernant l'étude de la performance de ces modèles, il a fallu utiliser de la cross validation le jeu de données étant mal réparti sur la variable Output.
#
# Enfin, grâce à la mise en place d'un workflow pour chacun des modèles, nous avons pu encore améliorer les performances en sélectionnant certaines variables de chaque catégorie.
#
# ##### Concernant les résultats : <br>
# Pour le Random Forest qui donne les meilleurs résultats en termes d'accuracy, recall et f1 :
#
# * Accuracy : 0.7728
# * Recall : 0.4264
# * F1 : 0.5109
#
# En termes d'accuracy, et au vu du déséquilibre du dataset, la performance est satisfaisante.
#
# Au niveau du Recall qui est assez faible, cela traduit le fait que notre modèle est "pointilleux". Il génère peu de faux positifs, mais passe à côté de bonnes prédictions.
#
# Le F1 score est donc assez bas ce qui est dû au Recall lui-même faible.
#
# #### Quelques pistes
# Cela étant dit voici quelques pistes d'améliorations pour cette analyse, que je n'aurais pas le temps de faire :
#
# * AdaBoost : Méthode de boosting pour la classification qui mêle classifieur "faible" et "fort" et qui tend à améliorer les résultats. A tester avec un nombre de features réduit.
# * Formaliser la recherche du minimum de features : Enlever de fait les features qui apparaissent redondantes dès la partie 3. Pour le reste des features, envisager un plan d'expérience afin d'obtenir le meilleur modèle possible. Cela prend du temps tout de même car il faut choisir à chaque fois les meilleurs hyperparamètres pour le classifieur et effectuer la cross validation.
#
# ------------------------------------------------------------------------------------------------------------------
# @Author : Elouan RAYMOND | github : keyserwood
