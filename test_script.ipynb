# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# 1. Effectuez toutes les opérations détaillées ci-dessous. 
# 2. Ces modules peuvent vous aidez mais si vous voulez/pouvez faire sans c'est possible aussi.
# 3. Vous pouvez utiliser internet sans limite, ce ne sera pas pénalisé.
# 4. Si vous êtes bloqué par un détail technique, n'hésitez pas à poser des questions.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# ### 1. CHARGER LES DONNEES DISPONIBLES SUR data_path

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
df = df.iloc[:,1:]

# %%
df
# Out:
#      target  feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0         1  -1.730291  -0.387338   0.487070  -0.292136   0.494670  -0.401048
# 1         0  -1.726771   0.349439  -0.295030   0.875140  -0.904533   0.413452
# 2         1  -1.723251  -4.615875   3.713153  -4.071849   1.289464  -4.443616
# 3         1  -1.719730   0.170963  -0.208896   0.172452  -0.404973   0.113894
# 4         0  -1.716210   0.487155  -0.350341   0.468695  -0.953869   1.031865
# ..      ...        ...        ...        ...        ...        ...        ...
# 979       0   1.716210   0.826114  -0.602350   0.148381  -0.949151   0.936274
# 980       1   1.719730   0.153829   0.342849   0.143081   0.348901   0.265120
# 981       1   1.723251   0.378863   0.343685   0.059724   1.096974   0.582023
# 982       1   1.726771   0.513143   0.500449  -0.368685   1.182913   0.765839
# 983       1   1.730291  -4.268985   3.443873  -3.823065   1.276920  -4.149654
#
#      feature_6  feature_7  feature_8  ...  feature_20  feature_21  feature_22  \
# 0    -0.115505  -0.503686   0.105604  ...   -0.486354    0.842223   -0.030120
# 1     0.515698   0.555202  -0.051086  ...    0.004795   -0.200540   -0.268520
# 2    -2.352370  -2.806933   3.715778  ...    1.348577    0.520080   -1.762644
# 3    -0.221955   0.015951  -0.035388  ...    0.118566    0.160616    0.875509
# 4     2.282005   0.545784   0.046143  ...    0.001453   -0.145620   -0.077028
# ..         ...        ...        ...  ...         ...         ...         ...
# 979   2.308580   0.390146   0.097410  ...   -0.312843   -0.233111   -0.717900
# 980  -0.300504   0.131807   0.141013  ...    0.085083    0.022360   -0.559016
# 981   0.123118   0.396612   0.056251  ...    0.273019   -0.092429   -0.465234
# 982  -0.974641   0.332982  -0.038395  ...    0.066759   -0.071528   -0.562313
# 983  -2.270327  -2.644885   3.452347  ...    1.321154    0.513668   -1.639099
#
#      feature_23  feature_24  feature_25  feature_26  feature_27  feature_28  \
# 0      0.331779   -0.120195   -0.478258   -0.572009   -0.269279   -0.282569
# 1     -0.311021   -0.931405    0.487842   -1.436342    0.092450   -0.335246
# 2     -1.067554    0.414838    2.914673   -0.512281    1.219054    0.804733
# 3      0.100104   -0.485972   -0.154115    0.111193   -0.063643   -0.293079
# 4     -0.113516    2.033598   -0.341834    0.635376   -0.203081   -0.497909
# ..          ...         ...         ...         ...         ...         ...
# 979    0.343896    1.403237   -0.426142    0.375732   -0.139851   -0.267073
# 980   -0.254242   -1.154201    0.540121    0.038414    0.301223    0.594390
# 981   -0.168203   -1.826180    0.428772    1.044603    0.142518    0.172105
# 982   -0.453422   -1.221184    2.053468    1.069414    0.435253    0.843338
# 983   -1.038436    0.406853    2.650430   -0.529414    1.282185    0.848841
#
#      feature_29
# 0     -0.407434
# 1     -0.407434
# 2     -0.022061
# 3     -0.344912
# 4     -0.388514
# ..          ...
# 979   -0.404359
# 980   -0.385555
# 981   -0.234154
# 982   -0.407434
# 983   -0.022061
#
# [984 rows x 31 columns]

# %%
df.describe()
# Out:
#            target     feature_0     feature_1     feature_2     feature_3  \
# count  984.000000  9.840000e+02  9.840000e+02  9.840000e+02  9.840000e+02
# mean     0.500000  1.218537e-17  5.867032e-17 -2.707861e-18 -1.444193e-17
# std      0.500254  1.000509e+00  1.000509e+00  1.000509e+00  1.000509e+00
# min      0.000000 -1.730291e+00 -5.108103e+00 -3.546712e+00 -4.420592e+00
# 25%      0.000000 -8.651457e-01 -7.959079e-02 -5.269067e-01 -2.666478e-01
# 50%      0.500000  0.000000e+00  2.990436e-01 -2.303167e-01  3.533802e-01
# 75%      1.000000  8.651457e-01  6.180872e-01  2.626271e-01  6.228648e-01
# max      1.000000  1.730291e+00  8.896628e-01  5.459224e+00  1.175598e+00
#
#           feature_4     feature_5     feature_6     feature_7     feature_8  \
# count  9.840000e+02  9.840000e+02  9.840000e+02  9.840000e+02  9.840000e+02
# mean   1.466758e-17 -2.166289e-17 -8.755417e-17 -3.565350e-17 -2.572468e-17
# std    1.000509e+00  1.000509e+00  1.000509e+00  1.000509e+00  1.000509e+00
# min   -2.122168e+00 -4.859951e+00 -3.744820e+00 -6.962026e+00 -8.533894e+00
# 25%   -7.361796e-01 -4.878632e-02 -4.893830e-01 -5.868545e-02 -1.094715e-01
# 50%   -2.829224e-01  2.679242e-01  1.713149e-02  3.764279e-01 -3.467060e-02
# 75%    6.114801e-01  4.766479e-01  4.500697e-01  5.227898e-01  1.155088e-01
# max    3.073645e+00  3.099401e+00  4.448985e+00  1.462011e+00  4.061933e+00
#
#        ...  feature_20    feature_21    feature_22    feature_23  \
# count  ...  984.000000  9.840000e+02  9.840000e+02  9.840000e+02
# mean   ...    0.000000  3.384826e-19  4.964412e-18 -2.752992e-17
# std    ...    1.000509  1.000509e+00  1.000509e+00  1.000509e+00
# min    ...   -5.969698 -8.324119e+00 -7.569982e+00 -1.644455e+01
# 25%    ...   -0.354390 -1.889592e-01 -4.652391e-01 -1.922695e-01
# 50%    ...   -0.142520 -7.712515e-02 -1.063168e-02 -1.598214e-02
# 75%    ...    0.227284  1.078073e-01  4.824382e-01  1.678632e-01
# max    ...    9.750946  9.652235e+00  7.109029e+00  4.691888e+00
#
#          feature_24    feature_25    feature_26    feature_27    feature_28  \
# count  9.840000e+02  9.840000e+02  9.840000e+02  9.840000e+02  9.840000e+02
# mean   1.844730e-17  1.805241e-18  7.333790e-18  6.543998e-18 -2.335530e-17
# std    1.000509e+00  1.000509e+00  1.000509e+00  1.000509e+00  1.000509e+00
# min   -3.654082e+00 -7.088918e+00 -2.796898e+00 -7.255701e+00 -4.514273e+00
# 25%   -6.281852e-01 -4.925746e-01 -6.569802e-01 -1.556289e-01 -2.577493e-01
# 50%    1.130816e-01  4.492610e-02 -5.845242e-02 -4.258112e-02 -2.530281e-02
# 75%    7.735475e-01  5.463562e-01  6.205539e-01  3.651893e-01  4.141885e-01
# max    2.404397e+00  3.222565e+00  6.184683e+00  2.923764e+00  4.128666e+00
#
#          feature_29
# count  9.840000e+02
# mean  -2.327068e-19
# std    1.000509e+00
# min   -4.113271e-01
# 25%   -4.063051e-01
# 50%   -3.374175e-01
# 75%   -2.206083e-02
# max    1.274563e+01
#
# [8 rows x 31 columns]

# %%
features_cols = [f'feature_{i}' for i in range(30)]

# %%
features = df[features_cols]

# %% [markdown]
# ### 2. VISUALISER LA VARIABLE target

# %%
df.groupby('target').count()
# Out:
#         feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# target
# 0             492        492        492        492        492        492
# 1             492        492        492        492        492        492
#
#         feature_6  feature_7  feature_8  feature_9  ...  feature_20  \
# target                                              ...
# 0             492        492        492        492  ...         492
# 1             492        492        492        492  ...         492
#
#         feature_21  feature_22  feature_23  feature_24  feature_25  \
# target
# 0              492         492         492         492         492
# 1              492         492         492         492         492
#
#         feature_26  feature_27  feature_28  feature_29
# target
# 0              492         492         492         492
# 1              492         492         492         492
#
# [2 rows x 30 columns]

# %% [markdown]
# Repartition 50/50

# %% [markdown]
# ### 3. ANALYSER LES CORRELATIONS ENTRE features & target

# %%
df.corr()
# Out:
#               target  feature_0  feature_1  feature_2  feature_3  feature_4  \
# target      1.000000  -0.051340  -0.415458   0.476361  -0.569833   0.701731
# feature_0  -0.051340   1.000000   0.006824   0.000123  -0.010883  -0.000112
# feature_1  -0.415458   0.006824   1.000000  -0.797012   0.877211  -0.597241
# feature_2   0.476361   0.000123  -0.797012   1.000000  -0.850670   0.658154
# feature_3  -0.569833  -0.010883   0.877211  -0.850670   1.000000  -0.766844
# feature_4   0.701731  -0.000112  -0.597241   0.658154  -0.766844   1.000000
# feature_5  -0.374466  -0.015607   0.856943  -0.800230   0.849597  -0.576848
# feature_6  -0.389668  -0.007045   0.316837  -0.265226   0.455191  -0.397202
# feature_7  -0.478678  -0.005224   0.882577  -0.841675   0.889872  -0.707904
# feature_8   0.051879   0.017006  -0.083805  -0.018935  -0.171825   0.099841
# feature_9  -0.556173  -0.009526   0.636835  -0.683458   0.759559  -0.788612
# feature_10 -0.629263  -0.004741   0.717065  -0.748604   0.850234  -0.788343
# feature_11  0.693433  -0.021519  -0.516101   0.601720  -0.718418   0.794150
# feature_28    0.301711   -0.268664    0.066196   -0.035278    0.172021
# feature_29    0.036255   -0.027746   -0.149659   -0.011764   -0.121730
#
#             feature_26  feature_27  feature_28  feature_29
# target        0.029947    0.080078    0.068579    0.064448
# feature_0     0.021684   -0.047147    0.019939    0.010066
# feature_1     0.076078    0.179484    0.174260   -0.023785
# feature_2    -0.019873   -0.164169    0.008173   -0.252834
# feature_3     0.016364    0.098435    0.128664   -0.010994
# feature_4     0.118265   -0.020506   -0.090761    0.029307
# feature_5     0.064769    0.196847    0.167388   -0.100907
# feature_6    -0.011128   -0.168002   -0.009396    0.168678
# feature_7     0.038414    0.228766    0.159676    0.123708
# feature_8     0.040937    0.286795   -0.012135    0.023378
# feature_9    -0.123284    0.149401    0.170433    0.028769
# feature_10   -0.019284    0.161800    0.164075    0.003860
# feature_11    0.124749    0.177774    0.012711   -0.011026
# feature_12   -0.102290   -0.022402    0.022287    0.023877
# feature_13    0.011898    0.060671   -0.119977   -0.012617
# feature_14   -0.167963   -0.206170   -0.111000    0.043233
# feature_15    0.076822    0.183487    0.098240    0.056808
# feature_16   -0.039562   -0.028219    0.028690   -0.009865
# feature_17   -0.034636    0.001043    0.063927   -0.015458
# feature_18    0.006113    0.053418    0.110092   -0.015796
# feature_19    0.038225    0.062122   -0.049516    0.050848
# feature_20    0.005050   -0.158980    0.064474    0.258079
# feature_21    0.022732    0.362140    0.301711    0.036255
# feature_22    0.022755   -0.356220   -0.268664   -0.027746
# feature_23    0.035803   -0.169296    0.066196   -0.149659
# feature_24   -0.087084   -0.207092   -0.035278   -0.011764
# feature_25    0.088321    0.215597    0.172021   -0.121730
# feature_26    1.000000    0.174659    0.030969   -0.046347
# feature_27    0.174659    1.000000    0.296519    0.045602
# feature_28    0.030969    0.296519    1.000000   -0.035090
# feature_29   -0.046347    0.045602   -0.035090    1.000000
#
# [31 rows x 31 columns]

# %% [markdown]
# ### 4.1. SEPARER LES DONNEES ENTRE variables explicatives & cible
# ### 4.2. SEPARER LES DONNEES ENTRE train_set ET test_set

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
X = features.values

# %%
y = df['target'].values

# %%
y.shape
y = np.reshape(y,(984,1))
y = [i[0] for i in y]

# %% [markdown]
# Reshaped data

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_train.shape
# Out:
# (738, 30)

# %% [markdown]
# ### 5.1. LANCER UN MODELE SIMPLE DE CLASSIFICATION SUR LES DONNEES
# ### 5.2. LES PREDICTION SONT ATTENDUES DANS UNE VARIABLE "y_pred"

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
classifier = RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
ypred = classifier.predict(X_test)

# %%
accuracy_score(ypred,y_test)
# Out:
# 0.9390243902439024

# %% [markdown]
# ### 6. TESTER VOTRE MODELE AVEC UNE METRIQUE DE VOTRE CHOIX

# %%
print('Accuracy Score:',accuracy_score(ypred,y_test))
# Out:
# Accuracy Score: 0.9512195121951219
